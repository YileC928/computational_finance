# %% [markdown]
# # Assignment2 | Yile Chen

# %% [markdown]
# ## Exercise 6
# A random variable (r.v.) is a function assigning a real number to every possible outcome of an experiment.
# A discrete random variable is a random variable that follows a discrete distribution.
# A continous random variable is a random variable that follows a continous distribution.

# %% [markdown]
# ## Exercise 7
# No, not necessarily.
# For example, let X = x, Z = 2x, and Y be U[0, 1]. Then Y is independent from both X and Z, but X and Z are not independent.

# %% [markdown]
# ## Exercise 8
# 1. X = x, Y = x + 1
# 2. X = -1, Y = |x|

# %% [markdown]
# ## Exercise 9
# $F(Y) = P(Y <= y) = P(\mu + \sigma X <= y) = P(X <= \frac{y - \mu}{\sigma}) = F(\frac{y - \mu}{\sigma}) $

# %% [markdown]
# ## Exercise 10

# %%
import numpy as np
sample1 = np.random.random(size=100)
sample2 = np.random.random(size=1000)
sample3 = np.random.random(size=10000)

# %%
import matplotlib.pyplot as plt
plt.hist(sample1, bins=100)
plt.show();
plt.hist(sample2, bins=100)
plt.show();
plt.hist(sample3, bins=100)
plt.show();

# %% [markdown]
# ## Exercise 11

# %%
def exp_pdf(x):
    if x > 0:
        rv = mu*math.e**(-mu*x)
    else:
        rv = 0
    return rv

# %%
x = np.linspace(-2, 2, 1000)

# %%
mu = 1
plt.plot(x, np.array(list(map(exp_pdf, x))))

# %%
mu = 5
plt.plot(x, np.array(list(map(exp_pdf, x))))

# %%
mu_list = [1, 3, 5, 7, 9]
for mu in mu_list:
    plt.plot(x, np.array(list(map(exp_pdf, x))))
    plt.legend("13579")

# %% [markdown]
# ## Exercise 12

# %%
exp_v = np.random.exponential(size=2000, scale=1/mu)
dunif_v = np.random.choice([1, -1], size=2000)
dbl_exp_v = exp_v*dunif_v

# %%
plt.hist(dbl_exp_v, bins = 100);
